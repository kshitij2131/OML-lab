# %% [markdown]
# #Question 1

# %% [markdown]
# ## Case 1

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max((x[0] - 2)**2 + (x[1] + 2)**2, (x[0])**2 + 8*x[1])

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == (x[0] - 2)**2 + (x[1] + 2)**2:
        subgrad = 2 * (x - np.array([2, -2]))
    else:
        subgrad = np.array([2*x[0], 8])
    return subgrad


x = np.array([0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# ## Case 2

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max((x[0] - 2)**2 + (x[1] + 2)**2, (x[0])**2 + 8*x[1])

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == (x[0] - 2)**2 + (x[1] + 2)**2:
        subgrad = 2 * (x - np.array([2, -2]))
    else:
        subgrad = np.array([2*x[0], 8])
    return subgrad


x = np.array([0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# #Question 2

# %% [markdown]
# ##Case 1

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max(5*(x[0]) + x[1], (x[0])**2 + (x[1]**2))

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == (5*(x[0]) + x[1]):
        subgrad = np.array([5,1])
    else:
        subgrad = 2*x
    return subgrad


x = np.array([0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    # alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# ##Case 2

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max(5*(x[0]) + x[1], (x[0])**2 + (x[1]**2))

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == (5*(x[0]) + x[1]):
        subgrad = np.array([5,1])
    else:
        subgrad = 2*x
    return subgrad


x = np.array([0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# #Question 3

# %% [markdown]
# ##Case 1

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max(x[0]**2 + x[1]**2 + x[2]**2 - 1, x[0]**2 + x[1]**2 + (x[2] - 2)**2)

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == (x[0]**2 + x[1]**2 + x[2]**2 - 1):
        subgrad = np.array([2 * x[0], 2 * x[1], 2 * x[2]])
    else:
        subgrad = np.array([2 * x[0], 2 * x[1], 2 * (x[2] - 2)])
    return subgrad


x = np.array([0.0, 0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    # alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)
    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# ## Case 2

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max(x[0]**2 + x[1]**2 + x[2]**2 - 1, x[0]**2 + x[1]**2 + (x[2] - 2)**2)

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == (x[0]**2 + x[1]**2 + x[2]**2 - 1):
        subgrad = np.array([2 * x[0], 2 * x[1], 2 * x[2]])
    else:
        subgrad = np.array([2 * x[0], 2 * x[1], 2 * (x[2] - 2)])
    return subgrad


x = np.array([0.0, 0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# #Question 4

# %% [markdown]
# ## Case 1

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max(x[0] + x[1] + x[2] - 1 , x[0] + x[1] - x[2] + 1)

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == (x[0] + x[1] + x[2] - 1):
        subgrad = np.array([1, 1, 1])
    else:
        subgrad = np.array([1, 1, -1])
    return subgrad


x = np.array([0.0, 0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    # alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# ##Case 2

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max(x[0] + x[1] + x[2] - 1 , x[0] + x[1] - x[2] + 1)

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == (x[0] + x[1] + x[2] - 1):
        subgrad = np.array([1, 1, 1])
    else:
        subgrad = np.array([1, 1, -1])
    return subgrad


x = np.array([0.0, 0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# #Question 5

# %% [markdown]
# ## Case 1

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max(2*x[0]**2 + 6*x[1]**2 + 2*(5*x[2] - x[0])**2 , x[0]**2 - 9*x[2])

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == ((x[0]**2) - (9*x[2])):
        subgrad = np.array([2*x[0], 0, -9])
    else:
        subgrad = np.array([4*x[0] - 4*(5*x[2] - x[0]), 12*x[1], 20*(5*x[2] - x[0])])
    return subgrad


x = np.array([0.0, 0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    # alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()
# Out:
# <ipython-input-27-eab7d5d84982>:9: RuntimeWarning: overflow encountered in double_scalars
#   return max(2*x[0]**2 + 6*x[1]**2 + 2*(5*x[2] - x[0])**2 , x[0]**2 - 9*x[2])
# <ipython-input-27-eab7d5d84982>:13: RuntimeWarning: overflow encountered in double_scalars
#   if f(x) == ((x[0]**2) - (9*x[2])):

# %% [markdown]
# ##Case 2

# %%
import numpy as np
import matplotlib.pyplot as plt

#Roll No. is B20CS028
r = 8

# objective function evaluated at x
def f(x):
    return max(2*x[0]**2 + 6*x[1]**2 + 2*(5*x[2] - x[0])**2 , x[0]**2 - 9*x[2])

# subgradient of the objective function evaluated at x
def subgradient_f(x):
    if f(x) == ((x[0]**2) - (9*x[2])):
        subgrad = np.array([2*x[0], 0, -9])
    else:
        subgrad = np.array([4*x[0] - 4*(5*x[2] - x[0]), 12*x[1], 20*(5*x[2] - x[0])])
    return subgrad


x = np.array([0.0, 0.0, 0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()

# %% [markdown]
# #Question 6

# %% [markdown]
# ##Case 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Roll no is B20CS028
r = 8

def g11(x):
    return x[0]**2 + x[1]**2 + 2*x[2]**2 + x[3]**2 - 5*x[0] - 5*x[1] - 21*x[2] + 7*x[3]

def g12(x):
    return g11(x) + 10*(x[0]**2 + x[1]**2 + x[2]**2 + x[3]**2 + x[0] - x[1] + x[2] - x[3] - 8)

def g21(x):
    return g11(x) + 10*(x[0]**2 + 2*x[1]**2 + x[2]**2 + 2*x[3]**2 - x[0] - x[3] - 10)

def g22(x):
    return g11(x) + 10*(2*x[0]**2 + x[1]**2 + x[2]**2 + 2*x[0] - x[1] - x[3] - 5)

def f(x):
  return max(g21(x),g22(x))

def subgradient_g21(x):
    x1 = x[0]
    x2 = x[1]
    x3 = x[2]
    x4 = x[3]
    return np.array([22*x1-15,42*x2-5, 24*x3-21,42*x4-3])

def subgradient_g22(x):
    x1 = x[0]
    x2 = x[1]
    x3 = x[2]
    x4 = x[3]
    return np.array([42*x1+15, 22*x2-15, 24*x3 - 21, 2*x4 - 3])

def subgradient_f(x):

    if g21(x) > g22(x):
        subgrad = subgradient_g21(x)
    else:
        subgrad = subgradient_g22(x)

    return subgrad




x = np.array([0.0, 0.0, 0.0,0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    # alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()
# Out:
# <ipython-input-34-da3abb1c19e1>:8: RuntimeWarning: overflow encountered in double_scalars
#   return x[0]**2 + x[1]**2 + 2*x[2]**2 + x[3]**2 - 5*x[0] - 5*x[1] - 21*x[2] + 7*x[3]
# <ipython-input-34-da3abb1c19e1>:14: RuntimeWarning: overflow encountered in double_scalars
#   return g11(x) + 10*(x[0]**2 + 2*x[1]**2 + x[2]**2 + 2*x[3]**2 - x[0] - x[3] - 10)
# <ipython-input-34-da3abb1c19e1>:17: RuntimeWarning: overflow encountered in double_scalars
#   return g11(x) + 10*(2*x[0]**2 + x[1]**2 + x[2]**2 + 2*x[0] - x[1] - x[3] - 5)
# <ipython-input-34-da3abb1c19e1>:34: RuntimeWarning: overflow encountered in double_scalars
#   return np.array([42*x1+15, 22*x2-15, 24*x3 - 21, 2*x4 - 3])
# <ipython-input-34-da3abb1c19e1>:17: RuntimeWarning: invalid value encountered in double_scalars
#   return g11(x) + 10*(2*x[0]**2 + x[1]**2 + x[2]**2 + 2*x[0] - x[1] - x[3] - 5)
# <ipython-input-34-da3abb1c19e1>:60: RuntimeWarning: invalid value encountered in subtract
#   x = x - alpha*subgrad

# %% [markdown]
# ##Case 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Roll no is B20CS028
r = 8

def g11(x):
    return x[0]**2 + x[1]**2 + 2*x[2]**2 + x[3]**2 - 5*x[0] - 5*x[1] - 21*x[2] + 7*x[3]

def g12(x):
    return g11(x) + 10*(x[0]**2 + x[1]**2 + x[2]**2 + x[3]**2 + x[0] - x[1] + x[2] - x[3] - 8)

def g21(x):
    return g11(x) + 10*(x[0]**2 + 2*x[1]**2 + x[2]**2 + 2*x[3]**2 - x[0] - x[3] - 10)

def g22(x):
    return g11(x) + 10*(2*x[0]**2 + x[1]**2 + x[2]**2 + 2*x[0] - x[1] - x[3] - 5)

def f(x):
  return max(g21(x),g22(x))

def subgradient_g21(x):
    x1 = x[0]
    x2 = x[1]
    x3 = x[2]
    x4 = x[3]
    return np.array([22*x1-15,42*x2-5, 24*x3-21,42*x4-3])

def subgradient_g22(x):
    x1 = x[0]
    x2 = x[1]
    x3 = x[2]
    x4 = x[3]
    return np.array([42*x1+15, 22*x2-15, 24*x3 - 21, 2*x4 - 3])

def subgradient_f(x):

    if g21(x) > g22(x):
        subgrad = subgradient_g21(x)
    else:
        subgrad = subgradient_g22(x)

    return subgrad




x = np.array([0.0, 0.0, 0.0,0.0])
alpha = 1/5

iterations = []
fbest_values = []

max_iterations = 500

# Finding optimal value using Subgradient Descent Method
for k in range(1, max_iterations + 1):
    alpha = 1/(2+ k)
    subgrad = subgradient_f(x)
    x = x - alpha*subgrad
    fbest = f(x)

    if(k>1 and fbest_values[len(fbest_values)-1]<= fbest ):
      fbest = fbest_values[len(fbest_values)-1]

    iterations.append(k)
    fbest_values.append(fbest)

plt.plot(iterations, fbest_values)
plt.xlabel('Iteration')
plt.ylabel('f_best(x)')
plt.title('Subgradient Descent Method')
plt.show()
